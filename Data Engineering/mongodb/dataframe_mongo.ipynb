# %%
import pymongo 
import pandas as pd

# %%
client = pymongo.MongoClient('localhost',27017)

# %%
db = client['chapter3']

# %%
collection = db['income']

# %%
income_df = pd.DataFrame(list(collection.find()))

# %%
income_df.head()
# Out:
#                         _id  age          workclass   fnlwgt   education  \
# 0  60ff9e023a4f5413c452521e   39          State-gov    77516   Bachelors
# 1  60ff9e023a4f5413c452521f   50   Self-emp-not-inc    83311   Bachelors
# 2  60ff9e023a4f5413c4525220   38            Private   215646     HS-grad
# 3  60ff9e023a4f5413c4525221   53            Private   234721        11th
# 4  60ff9e023a4f5413c4525222   28            Private   338409   Bachelors
#
#   education-num       marital-status          occupation    relationship  \
# 0            13        Never-married        Adm-clerical   Not-in-family
# 1            13   Married-civ-spouse     Exec-managerial         Husband
# 2             9             Divorced   Handlers-cleaners   Not-in-family
# 3             7   Married-civ-spouse   Handlers-cleaners         Husband
# 4            13   Married-civ-spouse      Prof-specialty            Wife
#
#      race      sex capital-gain capital-loss hours-per-week  native-country  \
# 0   White     Male         2174            0             40   United-States
# 1   White     Male            0            0             13   United-States
# 2   White     Male            0            0             40   United-States
# 3   Black     Male            0            0             40   United-States
# 4   Black   Female            0            0             40            Cuba
#
#     label
# 0   <=50K
# 1   <=50K
# 2   <=50K
# 3   <=50K
# 4   <=50K

# %%
income_df.tail()
# Out:
#                             _id  age      workclass   fnlwgt    education  \
# 32556  60ff9e183a4f5413c452d14a   27        Private   257302   Assoc-acdm
# 32557  60ff9e183a4f5413c452d14b   40        Private   154374      HS-grad
# 32558  60ff9e183a4f5413c452d14c   58        Private   151910      HS-grad
# 32559  60ff9e183a4f5413c452d14d   22        Private   201490      HS-grad
# 32560  60ff9e183a4f5413c452d14e   52   Self-emp-inc   287927      HS-grad
#
#       education-num       marital-status          occupation relationship  \
# 32556            12   Married-civ-spouse        Tech-support         Wife
# 32557             9   Married-civ-spouse   Machine-op-inspct      Husband
# 32558             9              Widowed        Adm-clerical    Unmarried
# 32559             9        Never-married        Adm-clerical    Own-child
# 32560             9   Married-civ-spouse     Exec-managerial         Wife
#
#          race      sex capital-gain capital-loss hours-per-week  \
# 32556   White   Female            0            0             38
# 32557   White     Male            0            0             40
# 32558   White   Female            0            0             40
# 32559   White     Male            0            0             20
# 32560   White   Female        15024            0             40
#
#        native-country   label
# 32556   United-States   <=50K
# 32557   United-States    >50K
# 32558   United-States   <=50K
# 32559   United-States   <=50K
# 32560   United-States    >50K

# %%
income_df['age'].describe()
# Out:
# count    32561.000000
# mean        38.581647
# std         13.640433
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         48.000000
# max         90.000000
# Name: age, dtype: float64

# %%
income_df['education'].describe()
# Out:
# count        32561
# unique          16
# top        HS-grad
# freq         10501
# Name: education, dtype: object
